# %%
from math import e
import sympy
import numpy as np
import matplotlib.pyplot as plt

# %%
#ISOTERMAS PxV
Tr = 0.25
def Pressure_Dieterici(Tr,Vr):
    
    return (e**2*Tr*e**(-2/Tr*Vr))/(2*Vr - 1)

Vr = np.linspace(0, 5, 100)
Pr = Pressure_Dieterici(Tr,Vr)


plt.figure(figsize=(10,8)) 
plt.plot(Vr,Pr, color='#e000b7',markersize=8)
plt.title('Isoterma')
plt.ylabel('Pressão Reduzida (Pr)') 
plt.xlabel('Volume Reduzido (V)')
plt.show()

# %%
#ISOTERMAS PxV
Tr = 1
def Pressure_Dieterici(Tr,Vr):
    
    return (e**2*Tr*e**(-2/Tr*Vr))/(2*Vr - 1)

Vr = np.linspace(0, 5, 100)
Pr = Pressure_Dieterici(Tr,Vr)


plt.figure(figsize=(10,8)) 
plt.plot(Vr,Pr, color='#e000b7',markersize=8)
plt.title('Isotermas')
plt.ylabel('Pressão Reduzida (Pr)') 
plt.xlabel('Volume Reduzido (V)')
plt.show()
